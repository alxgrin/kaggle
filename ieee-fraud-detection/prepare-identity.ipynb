# %% [markdown]
# # Prepare identity
#
# Dataset Description
# -------------------
#
# In this competition you are predicting the probability that an online transaction is fraudulent, as denoted by the binary target `isFraud`.
#
# The data is broken into two files `identity` and `transaction`, which are joined by `TransactionID`. Not all transactions have corresponding identity information.
#
# ### Categorical Features - Identity
#
# *   `DeviceType`
# *   `DeviceInfo`
# *   `id_12` - `id_38`
#
# The `TransactionDT` feature is a timedelta from a given reference datetime (not an actual timestamp).
#
# You can read more about the data from [this post by the competition host](https://www.kaggle.com/c/ieee-fraud-detection/discussion/101203).
#
# Files
# -----
#
# *   **train\_{transaction, identity}.csv** - the training set
# *   **test\_{transaction, identity}.csv** - the test set (you must predict the `isFraud` value for these observations)
# *   **sample\_submission.csv** - a sample submission file in the correct format
#
# Link: https://www.kaggle.com/competitions/ieee-fraud-detection

# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler, LabelEncoder

# %%
# %load_ext nb_black

# %%
scaler = StandardScaler()
le = LabelEncoder()

# %%
test_identity_df = pd.read_csv(
    "../../data/ieee-fraud-detection/test_identity.csv"
).set_index("TransactionID")
test_identity_df
# Out:
#                id-01     id-02  id-03  id-04  id-05  id-06  id-07  id-08  \
# TransactionID
# 3663586        -45.0  280290.0    NaN    NaN    0.0    0.0    NaN    NaN
# 3663588          0.0    3579.0    0.0    0.0    0.0    0.0    NaN    NaN
# 3663597         -5.0  185210.0    NaN    NaN    1.0    0.0    NaN    NaN
# 3663601        -45.0  252944.0    0.0    0.0    0.0    0.0    NaN    NaN
# 3663602        -95.0  328680.0    NaN    NaN    7.0  -33.0    NaN    NaN
# ...              ...       ...    ...    ...    ...    ...    ...    ...
# 4170230        -20.0  473365.0    NaN    NaN    0.0    0.0    NaN    NaN
# 4170233         -5.0  489917.0    0.0    0.0   -4.0  -32.0    NaN    NaN
# 4170234         -5.0  110081.0    NaN    NaN   22.0  -31.0    NaN    NaN
# 4170236        -45.0  266704.0    NaN    NaN   -3.0  -10.0    NaN    NaN
# 4170239        -10.0  692090.0    0.0    0.0    0.0    0.0    NaN    NaN
#
#                id-09  id-10  ...                    id-31 id-32     id-33  \
# TransactionID                ...
# 3663586          NaN    NaN  ...  chrome 67.0 for android   NaN       NaN
# 3663588          0.0    0.0  ...  chrome 67.0 for android  24.0  1280x720
# 3663597          NaN    NaN  ...       ie 11.0 for tablet   NaN       NaN
# 3663601          0.0    0.0  ...  chrome 67.0 for android   NaN       NaN
# 3663602          NaN    NaN  ...  chrome 67.0 for android   NaN       NaN
# ...              ...    ...  ...                      ...   ...       ...
# 4170230          NaN    NaN  ...  chrome 71.0 for android   NaN       NaN
# 4170233          0.0    0.0  ...  chrome 71.0 for android   NaN       NaN
# 4170234          NaN    NaN  ...       mobile safari 10.0  32.0  1334x750
# 4170236          NaN    NaN  ...  chrome 43.0 for android   NaN       NaN
# 4170239          0.0    0.0  ...      samsung browser 8.2   NaN       NaN
#
#                         id-34 id-35 id-36  id-37  id-38  DeviceType  \
# TransactionID
# 3663586                   NaN     F     F      T      F      mobile
# 3663588        match_status:2     T     F      T      T      mobile
# 3663597                   NaN     F     T      T      F     desktop
# 3663601                   NaN     F     F      T      F      mobile
# 3663602                   NaN     F     F      T      F      mobile
# ...                       ...   ...   ...    ...    ...         ...
# 4170230                   NaN     F     F      T      F      mobile
# 4170233                   NaN     F     F      T      F      mobile
# 4170234        match_status:2     T     F      F      T      mobile
# 4170236                   NaN     F     F      T      F      mobile
# 4170239                   NaN     F     F      T      F      mobile
#
#                                 DeviceInfo
# TransactionID
# 3663586        MYA-L13 Build/HUAWEIMYA-L13
# 3663588               LGLS676 Build/MXB48T
# 3663597                        Trident/7.0
# 3663601        MYA-L13 Build/HUAWEIMYA-L13
# 3663602               SM-G9650 Build/R16NW
# ...                                    ...
# 4170230                           SM-J700M
# 4170233                           SM-J320M
# 4170234                         iOS Device
# 4170236        ALE-L23 Build/HuaweiALE-L23
# 4170239                            SAMSUNG
#
# [141907 rows x 40 columns]

# %%
train_identity_df = pd.read_csv(
    "../../data/ieee-fraud-detection/train_identity.csv"
).set_index("TransactionID")
train_identity_df.columns = train_identity_df.columns.str.replace("_", "-")
train_identity_df
# Out:
#                id-01     id-02  id-03  id-04  id-05  id-06  id-07  id-08  \
# TransactionID
# 2987004          0.0   70787.0    NaN    NaN    NaN    NaN    NaN    NaN
# 2987008         -5.0   98945.0    NaN    NaN    0.0   -5.0    NaN    NaN
# 2987010         -5.0  191631.0    0.0    0.0    0.0    0.0    NaN    NaN
# 2987011         -5.0  221832.0    NaN    NaN    0.0   -6.0    NaN    NaN
# 2987016          0.0    7460.0    0.0    0.0    1.0    0.0    NaN    NaN
# ...              ...       ...    ...    ...    ...    ...    ...    ...
# 3577521        -15.0  145955.0    0.0    0.0    0.0    0.0    NaN    NaN
# 3577526         -5.0  172059.0    NaN    NaN    1.0   -5.0    NaN    NaN
# 3577529        -20.0  632381.0    NaN    NaN   -1.0  -36.0    NaN    NaN
# 3577531         -5.0   55528.0    0.0    0.0    0.0   -7.0    NaN    NaN
# 3577534        -45.0  339406.0    NaN    NaN  -10.0 -100.0    NaN    NaN
#
#                id-09  id-10  ...                    id-31 id-32      id-33  \
# TransactionID                ...
# 2987004          NaN    NaN  ...      samsung browser 6.2  32.0  2220x1080
# 2987008          NaN    NaN  ...       mobile safari 11.0  32.0   1334x750
# 2987010          0.0    0.0  ...              chrome 62.0   NaN        NaN
# 2987011          NaN    NaN  ...              chrome 62.0   NaN        NaN
# 2987016          0.0    0.0  ...              chrome 62.0  24.0   1280x800
# ...              ...    ...  ...                      ...   ...        ...
# 3577521          0.0    0.0  ...  chrome 66.0 for android   NaN        NaN
# 3577526          NaN    NaN  ...  chrome 55.0 for android  32.0    855x480
# 3577529          NaN    NaN  ...  chrome 65.0 for android   NaN        NaN
# 3577531          0.0    0.0  ...              chrome 66.0  24.0  2560x1600
# 3577534          NaN    NaN  ...  chrome 66.0 for android   NaN        NaN
#
#                         id-34 id-35 id-36  id-37  id-38  DeviceType  \
# TransactionID
# 2987004        match_status:2     T     F      T      T      mobile
# 2987008        match_status:1     T     F      F      T      mobile
# 2987010                   NaN     F     F      T      T     desktop
# 2987011                   NaN     F     F      T      T     desktop
# 2987016        match_status:2     T     F      T      T     desktop
# ...                       ...   ...   ...    ...    ...         ...
# 3577521                   NaN     F     F      T      F      mobile
# 3577526        match_status:2     T     F      T      F      mobile
# 3577529                   NaN     F     F      T      F      mobile
# 3577531        match_status:2     T     F      T      F     desktop
# 3577534                   NaN     F     F      T      F      mobile
#
#                                        DeviceInfo
# TransactionID
# 2987004             SAMSUNG SM-G892A Build/NRD90M
# 2987008                                iOS Device
# 2987010                                   Windows
# 2987011                                       NaN
# 2987016                                     MacOS
# ...                                           ...
# 3577521                   F3111 Build/33.3.A.1.97
# 3577526                       A574BL Build/NMF26F
# 3577529        Moto E (4) Plus Build/NMA26.42-152
# 3577531                                     MacOS
# 3577534               RNE-L03 Build/HUAWEIRNE-L03
#
# [144233 rows x 40 columns]

# %%
df = pd.concat([train_identity_df, test_identity_df]).sort_index()
df["isTest"] = df.index.isin(test_identity_df.index).astype(int)
df
# Out:
#                id-01     id-02  id-03  id-04  id-05  id-06  id-07  id-08  \
# TransactionID
# 2987004          0.0   70787.0    NaN    NaN    NaN    NaN    NaN    NaN
# 2987008         -5.0   98945.0    NaN    NaN    0.0   -5.0    NaN    NaN
# 2987010         -5.0  191631.0    0.0    0.0    0.0    0.0    NaN    NaN
# 2987011         -5.0  221832.0    NaN    NaN    0.0   -6.0    NaN    NaN
# 2987016          0.0    7460.0    0.0    0.0    1.0    0.0    NaN    NaN
# ...              ...       ...    ...    ...    ...    ...    ...    ...
# 4170230        -20.0  473365.0    NaN    NaN    0.0    0.0    NaN    NaN
# 4170233         -5.0  489917.0    0.0    0.0   -4.0  -32.0    NaN    NaN
# 4170234         -5.0  110081.0    NaN    NaN   22.0  -31.0    NaN    NaN
# 4170236        -45.0  266704.0    NaN    NaN   -3.0  -10.0    NaN    NaN
# 4170239        -10.0  692090.0    0.0    0.0    0.0    0.0    NaN    NaN
#
#                id-09  id-10  ...  id-32      id-33           id-34  id-35  \
# TransactionID                ...
# 2987004          NaN    NaN  ...   32.0  2220x1080  match_status:2      T
# 2987008          NaN    NaN  ...   32.0   1334x750  match_status:1      T
# 2987010          0.0    0.0  ...    NaN        NaN             NaN      F
# 2987011          NaN    NaN  ...    NaN        NaN             NaN      F
# 2987016          0.0    0.0  ...   24.0   1280x800  match_status:2      T
# ...              ...    ...  ...    ...        ...             ...    ...
# 4170230          NaN    NaN  ...    NaN        NaN             NaN      F
# 4170233          0.0    0.0  ...    NaN        NaN             NaN      F
# 4170234          NaN    NaN  ...   32.0   1334x750  match_status:2      T
# 4170236          NaN    NaN  ...    NaN        NaN             NaN      F
# 4170239          0.0    0.0  ...    NaN        NaN             NaN      F
#
#               id-36 id-37  id-38  DeviceType                     DeviceInfo  \
# TransactionID
# 2987004           F     T      T      mobile  SAMSUNG SM-G892A Build/NRD90M
# 2987008           F     F      T      mobile                     iOS Device
# 2987010           F     T      T     desktop                        Windows
# 2987011           F     T      T     desktop                            NaN
# 2987016           F     T      T     desktop                          MacOS
# ...             ...   ...    ...         ...                            ...
# 4170230           F     T      F      mobile                       SM-J700M
# 4170233           F     T      F      mobile                       SM-J320M
# 4170234           F     F      T      mobile                     iOS Device
# 4170236           F     T      F      mobile    ALE-L23 Build/HuaweiALE-L23
# 4170239           F     T      F      mobile                        SAMSUNG
#
#                isTest
# TransactionID
# 2987004             0
# 2987008             0
# 2987010             0
# 2987011             0
# 2987016             0
# ...               ...
# 4170230             1
# 4170233             1
# 4170234             1
# 4170236             1
# 4170239             1
#
# [286140 rows x 41 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 286140 entries, 2987004 to 4170239
# Data columns (total 41 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   id-01       286140 non-null  float64
#  1   id-02       277848 non-null  float64
#  2   id-03       132805 non-null  float64
#  3   id-04       132805 non-null  float64
#  4   id-05       271615 non-null  float64
#  5   id-06       271615 non-null  float64
#  6   id-07       10214 non-null   float64
#  7   id-08       10214 non-null   float64
#  8   id-09       149264 non-null  float64
#  9   id-10       149264 non-null  float64
#  10  id-11       277756 non-null  float64
#  11  id-12       286140 non-null  object
#  12  id-13       257606 non-null  float64
#  13  id-14       151401 non-null  float64
#  14  id-15       277962 non-null  object
#  15  id-16       255087 non-null  object
#  16  id-17       275335 non-null  float64
#  17  id-18       95988 non-null   float64
#  18  id-19       275224 non-null  float64
#  19  id-20       274894 non-null  float64
#  20  id-21       10218 non-null   float64
#  21  id-22       10231 non-null   float64
#  22  id-23       10231 non-null   object
#  23  id-24       9487 non-null    float64
#  24  id-25       10171 non-null   float64
#  25  id-26       10210 non-null   float64
#  26  id-27       10231 non-null   object
#  27  id-28       277756 non-null  object
#  28  id-29       277756 non-null  object
#  29  id-30       148224 non-null  object
#  30  id-31       276907 non-null  object
#  31  id-32       148257 non-null  float64
#  32  id-33       143960 non-null  object
#  33  id-34       149980 non-null  object
#  34  id-35       277962 non-null  object
#  35  id-36       277962 non-null  object
#  36  id-37       277962 non-null  object
#  37  id-38       277962 non-null  object
#  38  DeviceType  277741 non-null  object
#  39  DeviceInfo  233723 non-null  object
#  40  isTest      286140 non-null  int64
# dtypes: float64(23), int64(1), object(17)
# memory usage: 91.7+ MB

# %%
(df.isna().sum() / len(df)).sort_values(ascending=False)
# Out:
# id-24         0.966845
# id-25         0.964454
# id-26         0.964318
# id-07         0.964304
# id-08         0.964304
# id-21         0.964290
# id-22         0.964245
# id-23         0.964245
# id-27         0.964245
# id-18         0.664542
# id-04         0.535874
# id-03         0.535874
# id-33         0.496890
# id-30         0.481988
# id-32         0.481873
# id-09         0.478353
# id-10         0.478353
# id-34         0.475851
# id-14         0.470885
# DeviceInfo    0.183187
# id-16         0.108524
# id-13         0.099720
# id-05         0.050762
# id-06         0.050762
# id-20         0.039302
# id-19         0.038149
# id-17         0.037761
# id-31         0.032267
# DeviceType    0.029353
# id-28         0.029300
# id-29         0.029300
# id-11         0.029300
# id-02         0.028979
# id-15         0.028580
# id-35         0.028580
# id-36         0.028580
# id-37         0.028580
# id-38         0.028580
# id-01         0.000000
# id-12         0.000000
# isTest        0.000000
# dtype: float64

# %% [markdown]
# # Feature engineering

# %% [markdown]
# ## Numeric

# %%
numeric_df = df._get_numeric_data().drop("isTest", axis=1).copy()
numeric_df
# Out:
#                id-01     id-02  id-03  id-04  id-05  id-06  id-07  id-08  \
# TransactionID
# 2987004          0.0   70787.0    NaN    NaN    NaN    NaN    NaN    NaN
# 2987008         -5.0   98945.0    NaN    NaN    0.0   -5.0    NaN    NaN
# 2987010         -5.0  191631.0    0.0    0.0    0.0    0.0    NaN    NaN
# 2987011         -5.0  221832.0    NaN    NaN    0.0   -6.0    NaN    NaN
# 2987016          0.0    7460.0    0.0    0.0    1.0    0.0    NaN    NaN
# ...              ...       ...    ...    ...    ...    ...    ...    ...
# 4170230        -20.0  473365.0    NaN    NaN    0.0    0.0    NaN    NaN
# 4170233         -5.0  489917.0    0.0    0.0   -4.0  -32.0    NaN    NaN
# 4170234         -5.0  110081.0    NaN    NaN   22.0  -31.0    NaN    NaN
# 4170236        -45.0  266704.0    NaN    NaN   -3.0  -10.0    NaN    NaN
# 4170239        -10.0  692090.0    0.0    0.0    0.0    0.0    NaN    NaN
#
#                id-09  id-10  ...  id-17  id-18  id-19  id-20  id-21  id-22  \
# TransactionID                ...
# 2987004          NaN    NaN  ...  166.0    NaN  542.0  144.0    NaN    NaN
# 2987008          NaN    NaN  ...  166.0    NaN  621.0  500.0    NaN    NaN
# 2987010          0.0    0.0  ...  121.0    NaN  410.0  142.0    NaN    NaN
# 2987011          NaN    NaN  ...  225.0    NaN  176.0  507.0    NaN    NaN
# 2987016          0.0    0.0  ...  166.0   15.0  529.0  575.0    NaN    NaN
# ...              ...    ...  ...    ...    ...    ...    ...    ...    ...
# 4170230          NaN    NaN  ...  225.0    NaN  153.0  325.0    NaN    NaN
# 4170233          0.0    0.0  ...  225.0   17.0  417.0  595.0    NaN    NaN
# 4170234          NaN    NaN  ...  166.0   15.0  122.0  177.0    NaN    NaN
# 4170236          NaN    NaN  ...  225.0   15.0  176.0  507.0    NaN    NaN
# 4170239          0.0    0.0  ...  225.0    NaN  266.0  127.0    NaN    NaN
#
#                id-24  id-25  id-26  id-32
# TransactionID
# 2987004          NaN    NaN    NaN   32.0
# 2987008          NaN    NaN    NaN   32.0
# 2987010          NaN    NaN    NaN    NaN
# 2987011          NaN    NaN    NaN    NaN
# 2987016          NaN    NaN    NaN   24.0
# ...              ...    ...    ...    ...
# 4170230          NaN    NaN    NaN    NaN
# 4170233          NaN    NaN    NaN    NaN
# 4170234          NaN    NaN    NaN   32.0
# 4170236          NaN    NaN    NaN    NaN
# 4170239          NaN    NaN    NaN    NaN
#
# [286140 rows x 23 columns]

# %%
numeric_df[numeric_df.columns] = scaler.fit_transform(numeric_df.fillna(0))
numeric_df
# Out:
#                   id-01     id-02     id-03     id-04     id-05     id-06  \
# TransactionID
# 2987004        0.744040 -0.625225 -0.059848  0.064284 -0.269624  0.403955
# 2987008        0.397763 -0.461389 -0.059848  0.064284 -0.269624  0.088768
# 2987010        0.397763  0.077901 -0.059848  0.064284 -0.269624  0.403955
# 2987011        0.397763  0.253624 -0.059848  0.064284 -0.269624  0.025730
# 2987016        0.744040 -0.993690 -0.059848  0.064284 -0.071304  0.403955
# ...                 ...       ...       ...       ...       ...       ...
# 4170230       -0.641068  1.717158 -0.059848  0.064284 -0.269624  0.403955
# 4170233        0.397763  1.813465 -0.059848  0.064284 -1.062900 -1.613244
# 4170234        0.397763 -0.396595 -0.059848  0.064284  4.093396 -1.550206
# 4170236       -2.372452  0.514710 -0.059848  0.064284 -0.864581 -0.226420
# 4170239        0.051486  2.989800 -0.059848  0.064284 -0.269624  0.403955
#
#                   id-07     id-08     id-09     id-10  ...     id-17  \
# TransactionID                                          ...
# 2987004       -0.142214  0.157637 -0.060508  0.079481  ... -0.362672
# 2987008       -0.142214  0.157637 -0.060508  0.079481  ... -0.362672
# 2987010       -0.142214  0.157637 -0.060508  0.079481  ... -1.318933
# 2987011       -0.142214  0.157637 -0.060508  0.079481  ...  0.891091
# 2987016       -0.142214  0.157637 -0.060508  0.079481  ... -0.362672
# ...                 ...       ...       ...       ...  ...       ...
# 4170230       -0.142214  0.157637 -0.060508  0.079481  ...  0.891091
# 4170233       -0.142214  0.157637 -0.060508  0.079481  ...  0.891091
# 4170234       -0.142214  0.157637 -0.060508  0.079481  ... -0.362672
# 4170236       -0.142214  0.157637 -0.060508  0.079481  ...  0.891091
# 4170239       -0.142214  0.157637 -0.060508  0.079481  ...  0.891091
#
#                   id-18     id-19     id-20     id-21    id-22     id-24  \
# TransactionID
# 2987004       -0.700402  1.331305 -1.434781 -0.170535 -0.17819 -0.180778
# 2987008       -0.700402  1.847440  0.638359 -0.170535 -0.17819 -0.180778
# 2987010       -0.700402  0.468903 -1.446428 -0.170535 -0.17819 -0.180778
# 2987011       -0.700402 -1.059900  0.679123 -0.170535 -0.17819 -0.180778
# 2987016        1.454544  1.246372  1.075117 -0.170535 -0.17819 -0.180778
# ...                 ...       ...       ...       ...      ...       ...
# 4170230       -0.700402 -1.210167 -0.380741 -0.170535 -0.17819 -0.180778
# 4170233        1.741870  0.514637  1.191585 -0.170535 -0.17819 -0.180778
# 4170234        1.454544 -1.412701 -1.242608 -0.170535 -0.17819 -0.180778
# 4170236        1.454544 -1.059900  0.679123 -0.170535 -0.17819 -0.180778
# 4170239       -0.700402 -0.471899 -1.533779 -0.170535 -0.17819 -0.180778
#
#                   id-25     id-26     id-32
# TransactionID
# 2987004       -0.184696 -0.188009  1.364417
# 2987008       -0.184696 -0.188009  1.364417
# 2987010       -0.184696 -0.188009 -1.016641
# 2987011       -0.184696 -0.188009 -1.016641
# 2987016       -0.184696 -0.188009  0.769153
# ...                 ...       ...       ...
# 4170230       -0.184696 -0.188009 -1.016641
# 4170233       -0.184696 -0.188009 -1.016641
# 4170234       -0.184696 -0.188009  1.364417
# 4170236       -0.184696 -0.188009 -1.016641
# 4170239       -0.184696 -0.188009 -1.016641
#
# [286140 rows x 23 columns]

# %% [markdown]
# ## Categorical

# %%
cat_columns = set(df.columns) - set(df._get_numeric_data().columns)
cat_columns
# Out:
# {'DeviceInfo',
#  'DeviceType',
#  'id-12',
#  'id-15',
#  'id-16',
#  'id-23',
#  'id-27',
#  'id-28',
#  'id-29',
#  'id-30',
#  'id-31',
#  'id-33',
#  'id-34',
#  'id-35',
#  'id-36',
#  'id-37',
#  'id-38'}

# %%
categorical_df = df[cat_columns].apply(le.fit_transform).copy()
categorical_df
# Out:
# /tmp/ipykernel_43850/671918063.py:1: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   categorical_df = df[cat_columns].apply(le.fit_transform).copy()
#                DeviceType  id-36  id-31  id-28  id-33  id-16  id-30  id-38  \
# TransactionID
# 2987004                 1      0    161      1    268      1      7      1
# 2987008                 1      0    130      1     80      1     70      1
# 2987010                 0      0     46      0    461      0     87      1
# 2987011                 0      0     46      1    461      1     87      1
# 2987016                 0      0     46      0     68      0     26      1
# ...                   ...    ...    ...    ...    ...    ...    ...    ...
# 4170230                 1      0     74      1    461      1     87      0
# 4170233                 1      0     74      0    461      0     87      0
# 4170234                 1      0    129      1     80      1     63      1
# 4170236                 1      0     22      1    461      1     87      0
# 4170239                 1      0    166      0    461      0     87      0
#
#                DeviceInfo  id-27  id-34  id-37  id-29  id-23  id-15  id-12  \
# TransactionID
# 2987004              1565      2      3      1      1      3      1      1
# 2987008              2693      2      2      0      1      3      1      1
# 2987010              2526      2      4      1      0      3      0      1
# 2987011              2799      2      4      1      1      3      1      1
# 2987016              1170      2      3      1      0      3      0      1
# ...                   ...    ...    ...    ...    ...    ...    ...    ...
# 4170230              2165      2      4      1      1      3      1      1
# 4170233              2106      2      4      1      0      3      0      1
# 4170234              2693      2      3      0      1      3      1      1
# 4170236               141      2      4      1      1      3      1      1
# 4170239              1529      2      4      1      0      3      0      1
#
#                id-35
# TransactionID
# 2987004            1
# 2987008            1
# 2987010            0
# 2987011            0
# 2987016            1
# ...              ...
# 4170230            0
# 4170233            0
# 4170234            1
# 4170236            0
# 4170239            0
#
# [286140 rows x 17 columns]

# %%
prep_df = numeric_df.join(categorical_df).join(df[["isTest"]])
prep_df
# Out:
#                   id-01     id-02     id-03     id-04     id-05     id-06  \
# TransactionID
# 2987004        0.744040 -0.625225 -0.059848  0.064284 -0.269624  0.403955
# 2987008        0.397763 -0.461389 -0.059848  0.064284 -0.269624  0.088768
# 2987010        0.397763  0.077901 -0.059848  0.064284 -0.269624  0.403955
# 2987011        0.397763  0.253624 -0.059848  0.064284 -0.269624  0.025730
# 2987016        0.744040 -0.993690 -0.059848  0.064284 -0.071304  0.403955
# ...                 ...       ...       ...       ...       ...       ...
# 4170230       -0.641068  1.717158 -0.059848  0.064284 -0.269624  0.403955
# 4170233        0.397763  1.813465 -0.059848  0.064284 -1.062900 -1.613244
# 4170234        0.397763 -0.396595 -0.059848  0.064284  4.093396 -1.550206
# 4170236       -2.372452  0.514710 -0.059848  0.064284 -0.864581 -0.226420
# 4170239        0.051486  2.989800 -0.059848  0.064284 -0.269624  0.403955
#
#                   id-07     id-08     id-09     id-10  ...  DeviceInfo  id-27  \
# TransactionID                                          ...
# 2987004       -0.142214  0.157637 -0.060508  0.079481  ...        1565      2
# 2987008       -0.142214  0.157637 -0.060508  0.079481  ...        2693      2
# 2987010       -0.142214  0.157637 -0.060508  0.079481  ...        2526      2
# 2987011       -0.142214  0.157637 -0.060508  0.079481  ...        2799      2
# 2987016       -0.142214  0.157637 -0.060508  0.079481  ...        1170      2
# ...                 ...       ...       ...       ...  ...         ...    ...
# 4170230       -0.142214  0.157637 -0.060508  0.079481  ...        2165      2
# 4170233       -0.142214  0.157637 -0.060508  0.079481  ...        2106      2
# 4170234       -0.142214  0.157637 -0.060508  0.079481  ...        2693      2
# 4170236       -0.142214  0.157637 -0.060508  0.079481  ...         141      2
# 4170239       -0.142214  0.157637 -0.060508  0.079481  ...        1529      2
#
#                id-34  id-37  id-29  id-23  id-15  id-12  id-35  isTest
# TransactionID
# 2987004            3      1      1      3      1      1      1       0
# 2987008            2      0      1      3      1      1      1       0
# 2987010            4      1      0      3      0      1      0       0
# 2987011            4      1      1      3      1      1      0       0
# 2987016            3      1      0      3      0      1      1       0
# ...              ...    ...    ...    ...    ...    ...    ...     ...
# 4170230            4      1      1      3      1      1      0       1
# 4170233            4      1      0      3      0      1      0       1
# 4170234            3      0      1      3      1      1      1       1
# 4170236            4      1      1      3      1      1      0       1
# 4170239            4      1      0      3      0      1      0       1
#
# [286140 rows x 41 columns]

# %% [markdown]
# # Save

# %%
prep_df.to_orc("../../data/ieee-fraud-detection/ieee_identity.orc")
