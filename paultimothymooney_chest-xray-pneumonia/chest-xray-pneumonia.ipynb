# %% [markdown]
# # Chest X-Ray Images (Pneumonia)
# 5,863 images, 2 categories
#
# ### Context
#
# [http://www.cell.com/cell/fulltext/S0092-8674(18)30154-5](http://www.cell.com/cell/fulltext/S0092-8674(18)30154-5)
#
# ![](https://i.imgur.com/jZqpV51.png)
#
# Figure S6. Illustrative Examples of Chest X-Rays in Patients with Pneumonia, Related to Figure 6
# The normal chest X-ray (left panel) depicts clear lungs without any areas of abnormal opacification in the image. Bacterial pneumonia (middle) typically exhibits a focal lobar consolidation, in this case in the right upper lobe (white arrows), whereas viral pneumonia (right) manifests with a more diffuse ‘‘interstitial’’ pattern in both lungs.
# [http://www.cell.com/cell/fulltext/S0092-8674(18)30154-5](http://www.cell.com/cell/fulltext/S0092-8674(18)30154-5)
#
# ### Content
#
# The dataset is organized into 3 folders (train, test, val) and contains subfolders for each image category (Pneumonia/Normal). There are 5,863 X-Ray images (JPEG) and 2 categories (Pneumonia/Normal).
#
# Chest X-ray images (anterior-posterior) were selected from retrospective cohorts of pediatric patients of one to five years old from Guangzhou Women and Children’s Medical Center, Guangzhou. All chest X-ray imaging was performed as part of patients’ routine clinical care.
#
# For the analysis of chest x-ray images, all chest radiographs were initially screened for quality control by removing all low quality or unreadable scans. The diagnoses for the images were then graded by two expert physicians before being cleared for training the AI system. In order to account for any grading errors, the evaluation set was also checked by a third expert.
#
# ### Acknowledgements
#
# Data: [https://data.mendeley.com/datasets/rscbjbr9sj/2](https://data.mendeley.com/datasets/rscbjbr9sj/2)
#
# License: [CC BY 4.0](https://creativecommons.org/licenses/by/4.0/)
#
# Citation: [http://www.cell.com/cell/fulltext/S0092-8674(18)30154-5](http://www.cell.com/cell/fulltext/S0092-8674(18)30154-5)
#
# ![enter image description here](https://i.imgur.com/8AUJkin.png)
#
# ### Inspiration
#
# Automated methods to detect and classify human diseases from medical images.
#
# Link: https://www.kaggle.com/datasets/paultimothymooney/chest-xray-pneumonia
#
# Help
#
# * https://www.kaggle.com/code/arunrk7/covid-19-detection-pytorch-tutorial
# * https://www.kaggle.com/code/krishnakalyan3/pneumonia-fastai-2-0-baseline

# %%
import numpy as np
import pandas as pd
from fastai.vision.all import *
import timm
from pathlib import Path

# %%
# %load_ext nb_black

# %%
# !tree -d ../../data/chest_xray/
# Out:
# ../../data/chest_xray/
# ├── models
# ├── test
# │   ├── NORMAL
# │   └── PNEUMONIA
# ├── train
# │   ├── NORMAL
# │   └── PNEUMONIA
# └── val
#     ├── NORMAL
#     └── PNEUMONIA
#
# 10 directories

# %% [markdown]
# # Prepare

# %%
path_list = list(Path("../../data/chest_xray/").rglob("*.jpeg"))

df = pd.DataFrame(
    {
        "image_id": [x.name for x in path_list],
        "path": [x.parts[-3] for x in path_list],
        "label": [x.parts[-2] for x in path_list],
        "imagePath": path_list,
    }
).set_index("image_id")
df["label"] = df["label"].replace({"NORMAL": 0, "PNEUMONIA": 1})
df
# Out:
#                                path  label  \
# image_id
# IM-0095-0001.jpeg              test      0
# NORMAL2-IM-0370-0001.jpeg      test      0
# NORMAL2-IM-0233-0001.jpeg      test      0
# IM-0030-0001.jpeg              test      0
# IM-0029-0001.jpeg              test      0
# ...                             ...    ...
# person642_virus_1223.jpeg     train      1
# person413_bacteria_1832.jpeg  train      1
# person670_bacteria_2563.jpeg  train      1
# person586_bacteria_2417.jpeg  train      1
# person736_virus_1358.jpeg     train      1
#
#                                                                                        imagePath
# image_id
# IM-0095-0001.jpeg                            ../../data/chest_xray/test/NORMAL/IM-0095-0001.jpeg
# NORMAL2-IM-0370-0001.jpeg            ../../data/chest_xray/test/NORMAL/NORMAL2-IM-0370-0001.jpeg
# NORMAL2-IM-0233-0001.jpeg            ../../data/chest_xray/test/NORMAL/NORMAL2-IM-0233-0001.jpeg
# IM-0030-0001.jpeg                            ../../data/chest_xray/test/NORMAL/IM-0030-0001.jpeg
# IM-0029-0001.jpeg                            ../../data/chest_xray/test/NORMAL/IM-0029-0001.jpeg
# ...                                                                                          ...
# person642_virus_1223.jpeg        ../../data/chest_xray/train/PNEUMONIA/person642_virus_1223.jpeg
# person413_bacteria_1832.jpeg  ../../data/chest_xray/train/PNEUMONIA/person413_bacteria_1832.jpeg
# person670_bacteria_2563.jpeg  ../../data/chest_xray/train/PNEUMONIA/person670_bacteria_2563.jpeg
# person586_bacteria_2417.jpeg  ../../data/chest_xray/train/PNEUMONIA/person586_bacteria_2417.jpeg
# person736_virus_1358.jpeg        ../../data/chest_xray/train/PNEUMONIA/person736_virus_1358.jpeg
#
# [5856 rows x 3 columns]

# %%
df["label"].value_counts(normalize=True)
# Out:
# 1    0.729679
# 0    0.270321
# Name: label, dtype: float64

# %%
X_train = df[df["path"] != "test"][["imagePath", "label"]]
X_train
# Out:
#                                                                                        imagePath  \
# image_id
# NORMAL2-IM-1430-0001.jpeg             ../../data/chest_xray/val/NORMAL/NORMAL2-IM-1430-0001.jpeg
# NORMAL2-IM-1436-0001.jpeg             ../../data/chest_xray/val/NORMAL/NORMAL2-IM-1436-0001.jpeg
# NORMAL2-IM-1431-0001.jpeg             ../../data/chest_xray/val/NORMAL/NORMAL2-IM-1431-0001.jpeg
# NORMAL2-IM-1442-0001.jpeg             ../../data/chest_xray/val/NORMAL/NORMAL2-IM-1442-0001.jpeg
# NORMAL2-IM-1440-0001.jpeg             ../../data/chest_xray/val/NORMAL/NORMAL2-IM-1440-0001.jpeg
# ...                                                                                          ...
# person642_virus_1223.jpeg        ../../data/chest_xray/train/PNEUMONIA/person642_virus_1223.jpeg
# person413_bacteria_1832.jpeg  ../../data/chest_xray/train/PNEUMONIA/person413_bacteria_1832.jpeg
# person670_bacteria_2563.jpeg  ../../data/chest_xray/train/PNEUMONIA/person670_bacteria_2563.jpeg
# person586_bacteria_2417.jpeg  ../../data/chest_xray/train/PNEUMONIA/person586_bacteria_2417.jpeg
# person736_virus_1358.jpeg        ../../data/chest_xray/train/PNEUMONIA/person736_virus_1358.jpeg
#
#                               label
# image_id
# NORMAL2-IM-1430-0001.jpeg         0
# NORMAL2-IM-1436-0001.jpeg         0
# NORMAL2-IM-1431-0001.jpeg         0
# NORMAL2-IM-1442-0001.jpeg         0
# NORMAL2-IM-1440-0001.jpeg         0
# ...                             ...
# person642_virus_1223.jpeg         1
# person413_bacteria_1832.jpeg      1
# person670_bacteria_2563.jpeg      1
# person586_bacteria_2417.jpeg      1
# person736_virus_1358.jpeg         1
#
# [5232 rows x 2 columns]

# %%
X_true = df[df["path"] == "test"][["imagePath", "label"]]
X_true
# Out:
#                                                                                     imagePath  \
# image_id
# IM-0095-0001.jpeg                         ../../data/chest_xray/test/NORMAL/IM-0095-0001.jpeg
# NORMAL2-IM-0370-0001.jpeg         ../../data/chest_xray/test/NORMAL/NORMAL2-IM-0370-0001.jpeg
# NORMAL2-IM-0233-0001.jpeg         ../../data/chest_xray/test/NORMAL/NORMAL2-IM-0233-0001.jpeg
# IM-0030-0001.jpeg                         ../../data/chest_xray/test/NORMAL/IM-0030-0001.jpeg
# IM-0029-0001.jpeg                         ../../data/chest_xray/test/NORMAL/IM-0029-0001.jpeg
# ...                                                                                       ...
# person1_virus_6.jpeg                ../../data/chest_xray/test/PNEUMONIA/person1_virus_6.jpeg
# person121_bacteria_580.jpeg  ../../data/chest_xray/test/PNEUMONIA/person121_bacteria_580.jpeg
# person147_bacteria_711.jpeg  ../../data/chest_xray/test/PNEUMONIA/person147_bacteria_711.jpeg
# person99_bacteria_474.jpeg    ../../data/chest_xray/test/PNEUMONIA/person99_bacteria_474.jpeg
# person1635_virus_2831.jpeg    ../../data/chest_xray/test/PNEUMONIA/person1635_virus_2831.jpeg
#
#                              label
# image_id
# IM-0095-0001.jpeg                0
# NORMAL2-IM-0370-0001.jpeg        0
# NORMAL2-IM-0233-0001.jpeg        0
# IM-0030-0001.jpeg                0
# IM-0029-0001.jpeg                0
# ...                            ...
# person1_virus_6.jpeg             1
# person121_bacteria_580.jpeg      1
# person147_bacteria_711.jpeg      1
# person99_bacteria_474.jpeg       1
# person1635_virus_2831.jpeg       1
#
# [624 rows x 2 columns]

# %%
BATCH_SIZE = 32
IMAGE_SIZE = 224

# %%
dls = ImageDataLoaders.from_df(
    X_train[["imagePath", "label"]],
    valid_pct=0.2,
    seed=42,
    bs=BATCH_SIZE,
    item_tfms=Resize(IMAGE_SIZE),
)

# %%
dls.train.show_batch()

# %%
dls.valid.show_batch()

# %% [markdown]
# # Train

# %%
# timm.list_models(pretrained=True)

# %%
model = timm.create_model("densenet121", pretrained=True, num_classes=dls.c)

# %%
learn = Learner(dls, model, metrics=accuracy).to_fp16()
learn

# %%
learn.lr_find()
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# SuggestedLRs(valley=0.00010964782268274575)

# %%
learn.fit_one_cycle(
    10,
    1e-4,
    cbs=[
        SaveModelCallback(
            monitor="accuracy",
            comp=np.greater,
            with_opt=True,
        ),
    ],
)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.342755</td>
#       <td>0.217534</td>
#       <td>0.934990</td>
#       <td>00:26</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.135962</td>
#       <td>0.097338</td>
#       <td>0.962715</td>
#       <td>00:26</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.067902</td>
#       <td>0.058157</td>
#       <td>0.975143</td>
#       <td>00:26</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.038378</td>
#       <td>0.067954</td>
#       <td>0.971319</td>
#       <td>00:27</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.023159</td>
#       <td>0.057300</td>
#       <td>0.977055</td>
#       <td>00:26</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.012392</td>
#       <td>0.034151</td>
#       <td>0.981836</td>
#       <td>00:26</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.007725</td>
#       <td>0.025706</td>
#       <td>0.990440</td>
#       <td>00:26</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.004227</td>
#       <td>0.029500</td>
#       <td>0.988528</td>
#       <td>00:26</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.003489</td>
#       <td>0.022432</td>
#       <td>0.994264</td>
#       <td>00:26</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.003926</td>
#       <td>0.022641</td>
#       <td>0.994264</td>
#       <td>00:26</td>
#     </tr>
#   </tbody>
# </table>
# Better model found at epoch 0 with accuracy value: 0.9349904656410217.
# Better model found at epoch 1 with accuracy value: 0.9627150893211365.
# Better model found at epoch 2 with accuracy value: 0.9751434326171875.
# Better model found at epoch 4 with accuracy value: 0.9770554304122925.
# Better model found at epoch 5 with accuracy value: 0.9818355441093445.
# Better model found at epoch 6 with accuracy value: 0.990439772605896.
# Better model found at epoch 8 with accuracy value: 0.9942638874053955.

# %%
learn.recorder.plot_loss()

# %%
learn.show_results()
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>

# %% [markdown]
# # Validate

# %%
test_dl = dls.test_dl(X_true[["imagePath", "label"]])
test_dl.show_batch()

# %%
preds, _ = learn.tta(dl=test_dl, n=5, beta=0)
preds
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='0' class='' max='10' style='width:300px; height:20px; vertical-align: middle;'></progress>
#
#     </div>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# tensor([[6.7598e-01, 3.2402e-01],
#         [9.9587e-01, 4.1319e-03],
#         [1.3107e-03, 9.9869e-01],
#         ...,
#         [1.6615e-04, 9.9983e-01],
#         [3.4483e-04, 9.9966e-01],
#         [2.5023e-05, 9.9998e-01]])

# %%
(X_true["label"] == preds.argmax(dim=-1).numpy()).sum() / len(X_true)
# Out:
# 0.8365384615384616
